# %% [markdown]
# <a href="https://colab.research.google.com/github/harsha361/pytorch_linreg1/blob/main/pytorch_linreg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing modules
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
#hyper parameters
input_size=1
output_size=1
num_epochs=1000
learning_rate=0.001
#toy data set
x_train=np.array([[3.3], [4.4], [5.5], [6.71], [6.93], [4.168],
                    [9.779], [6.182], [7.59], [2.167], [7.042],
                    [10.791], [5.313], [7.997], [3.1]], dtype=np.float32)
y_train = np.array([[1.7], [2.76], [2.09], [3.19], [1.694], [1.573],
                    [3.366], [2.596], [2.53], [1.221], [2.827],
                    [3.465], [1.65], [2.904], [1.3]], dtype=np.float32)
x_train,y_train
#lin_regression model
model=nn.Linear(input_size,output_size)
#loss and optimizer
criterion=nn.MSELoss()
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)
#training the model
for epoch in range(num_epochs):
  inputs=torch.from_numpy(x_train)
  targets=torch.from_numpy(y_train)
#forward pass
  outputs=model(inputs)
  loss=criterion(outputs,targets)
#backward and optimize
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  if (epoch+1)%5==0:
    print(f'Epoch:{epoch+1},loss:{loss:.4f}')

#plotting the graph
predicted = model(torch.from_numpy(x_train)).detach().numpy()
plt.plot(x_train,y_train,'ro',label="originaldata")
plt.plot(x_train,predicted,label="fittedline")
plt.legend()
plt.show()
# Out:
# Epoch:5,loss:0.4215
# Epoch:10,loss:0.2803
# Epoch:15,loss:0.2231
# Epoch:20,loss:0.1999
# Epoch:25,loss:0.1904
# Epoch:30,loss:0.1866
# Epoch:35,loss:0.1850
# Epoch:40,loss:0.1844
# Epoch:45,loss:0.1841
# Epoch:50,loss:0.1839
# Epoch:55,loss:0.1838
# Epoch:60,loss:0.1838
# Epoch:65,loss:0.1837
# Epoch:70,loss:0.1837
# Epoch:75,loss:0.1837
# Epoch:80,loss:0.1836
# Epoch:85,loss:0.1836
# Epoch:90,loss:0.1836
# Epoch:95,loss:0.1835
# Epoch:100,loss:0.1835
# Epoch:105,loss:0.1834
# Epoch:110,loss:0.1834
# Epoch:115,loss:0.1834
# Epoch:120,loss:0.1833
# Epoch:125,loss:0.1833
# Epoch:130,loss:0.1833
# Epoch:135,loss:0.1832
# Epoch:140,loss:0.1832
# Epoch:145,loss:0.1831
# Epoch:150,loss:0.1831
# Epoch:155,loss:0.1831
# Epoch:160,loss:0.1830
# Epoch:165,loss:0.1830
# Epoch:170,loss:0.1830
# Epoch:175,loss:0.1829
# Epoch:180,loss:0.1829
# Epoch:185,loss:0.1829
# Epoch:190,loss:0.1828
# Epoch:195,loss:0.1828
# Epoch:200,loss:0.1827
# Epoch:205,loss:0.1827
# Epoch:210,loss:0.1827
# ...
